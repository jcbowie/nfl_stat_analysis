# %%
import pandas as pd
from pprint import pprint as pp
import datetime as dt
from sklearn import preprocessing

# %%
df = pd.read_csv("../data/2019_averages.csv")

# %%
df.head()
# Out:
#    season  week gameDate gameTimeEastern homeNickname visitorNickname  siteId  \
# 0  2019.0   1.0   9/5/19        20:20:00        Bears         Packers  4620.0
# 1  2019.0   1.0   9/8/19        13:00:00     Panthers            Rams  1769.0
# 2  2019.0   1.0   9/8/19        13:00:00       Eagles        Redskins  2769.0
# 3  2019.0   1.0   9/8/19        13:00:00         Jets           Bills  3757.0
# 4  2019.0   1.0   9/8/19        13:00:00      Vikings         Falcons  1652.0
#
#           siteCity siteState roofType  ...  VpuntReturnsTouchdowns  \
# 0          Chicago        IL  OUTDOOR  ...                  0.0125
# 1        Charlotte        NC  OUTDOOR  ...                  0.0250
# 2     Philadelphia        PA  OUTDOOR  ...                  0.0125
# 3  East Rutherford        NJ  OUTDOOR  ...                  0.0000
# 4      Minneapolis        MN   INDOOR  ...                  0.0000
#
#    VreceivingReceptions  VreceivingTouchdowns  VreceivingLong  \
# ...

# %%
mapping_dictionary = {
    '49ers': 1,
    'Bears': 2,
    'Bengals': 3,
    'Bills': 4,
    'Broncos': 5,
    'Browns': 6,
    'Buccaneers': 7,
    'Cardinals': 8,
    'Chargers': 9,
    'Chiefs': 10,
    'Colts': 11,
    'Cowboys': 12,
    'Dolphins': 13,
    'Eagles': 14,
    'Falcons': 15,
    'Giants': 16,
    'Jaguars': 17,
    'Jets': 18,
    'Lions': 19,
    'Packers': 20,
    'Panthers': 21,
    'Patriots': 22,
    'Raiders': 23,
    'Rams': 24,
    'Ravens': 25,
    'Redskins': 26,
    'Saints': 27,
    'Seahawks': 28,
    'Steelers': 29,
    'Texans': 30,
    'Titans': 31,
    'Vikings': 32,
    'INDOOR': 1,
    'OUTDOOR': 2,
    'RETRACTABLE': 3,
    'Arlington': 1,
    'Atlanta': 2,
    'Baltimore': 3,
    'Carson': 4,
    'Charlotte': 5,
    'Chicago': 6,
    'Cincinnati': 7,
    'Cleveland': 8,
    'Denver': 9,
    'Detroit': 10,
    'East Rutherford': 11,
    'Foxborough': 12,
    'Glendale': 13,
    'Green Bay': 14,
    'Houston': 15,
    'Indianapolis': 16,
    'Jacksonville': 17,
    'Kansas City': 18,
    'Landover': 19,
    'London': 20,
    'Los Angeles': 21,
    'Mexico City': 22,
    'Miami Gardens': 23,
    'Minneapolis': 24,
    'Nashville': 25,
    'New Orleans': 26,
    'Oakland': 27,
    'Opa Locka': 28,
    'Orchard Park': 29,
    'Philadelphia': 30,
    'Pittsburgh': 31,
    'San Diego': 32,
    'San Francisco': 33,
    'Santa Clara': 34,
    'Seattle': 35,
    'St. Louis': 36,
    'St.Louis': 37,
    'Tampa': 38,
    'Toronto': 39,
    'Twickenham': 40,
    None: 23,
    'AZ': 12,
    'CA': 15,
    'CO': 21,
    'FL': 3,
    'GA': 2,
    'IL': 20,
    'IN': 5,
    'LA': 4,
    'MA': 14,
    'MD': 7,
    'MI': 16,
    'MN': 22,
    'MO': 18,
    'NC': 8,
    'NJ': 11,
    'NY': 19,
    'OH': 9,
    'ON': 24,
    'PA': 1,
    'TN': 17,
    'TX': 6,
    'WA': 10,
    'WI': 13,
    '12:30:00': 8,
    '13:00:00': 2,
    '16:05:00': 7,
    '16:15:00': 3,
    '16:25:00': 12,
    '16:30:00': 18,
    '19:00:00': 5,
    '19:10:00': 13,
    '19:20:00': 10,
    '19:30:00': 9,
    '20:00:00': 11,
    '20:15:00': 20,
    '20:20:00': 4,
    '20:25:00': 15,
    '20:30:00': 1,
    '20:40:00': 16,
    '22:15:00': 6,
    '22:20:00': 14,
    '23:35:00': 17,
    '9:30:00': 19
}

# %%
df_mapped = df.replace(mapping_dictionary)

# %%
df_mapped
# Out:
#      season  week  gameDate  gameTimeEastern  homeNickname  visitorNickname  \
# 0    2019.0   1.0    9/5/19                4             2               20
# 1    2019.0   1.0    9/8/19                2            21               24
# 2    2019.0   1.0    9/8/19                2            14               26
# 3    2019.0   1.0    9/8/19                2            18                4
# 4    2019.0   1.0    9/8/19                2            32               15
# ..      ...   ...       ...              ...           ...              ...
# 251  2019.0  17.0  12/29/19                2             4               18
# 252  2019.0  17.0  12/29/19                2            21               27
# 253  2019.0  17.0  12/29/19               12             5               23
# 254  2019.0  17.0  12/29/19               12            28                1
# 255  2019.0  17.0  12/29/19               12            24                8
#
# ...

# %%
for col, col_data in df.iteritems():
    if col_data.dtype == object:
        print(col)
# Out:
# gameDate
# gameTimeEastern
# homeNickname
# visitorNickname
# siteCity
# siteState
# roofType

# %%
df_mapped = df_mapped.drop('gameDate', axis=1)

# %%
columns_not_standard = ['gameTimeEastern', 'homeNickname', 'visitorNickname',
                        'siteCity', 'siteState', 'roofType']

# %%
df_standard = df_mapped.drop(columns_not_standard, axis=1)
df_objects = df_mapped[columns_not_standard]

# %%
df_objects.head()
# Out:
#    gameTimeEastern  homeNickname  visitorNickname siteCity  siteState  \
# 0                4             2               20        6         20
# 1                2            21               24        5          8
# 2                2            14               26       30          1
# 3                2            18                4       11         11
# 4                2            32               15       24         22
#
#    roofType
# 0         2
# 1         2
# 2         2
# 3         2
# 4         1

# %%
cols = df_standard.columns

# %%
scaler = preprocessing.MinMaxScaler()
df_clean_array = scaler.fit_transform(df_standard)
df_standard = pd.DataFrame(df_clean_array)

# %%
df_standard.columns = cols

# %%
df_standard.head()
# Out:
#    season  week    siteId  visitorTeamScore  homeTeamScore  HfirstDownsTotal  \
# 0     0.0   0.0  0.753905               0.0            0.0          0.192884
# 1     0.0   0.0  0.152174               0.0            0.0          0.299625
# 2     0.0   0.0  0.363233               0.0            0.0          0.496255
# 3     0.0   0.0  0.571760               0.0            0.0          0.116105
# 4     0.0   0.0  0.127480               0.0            0.0          0.308989
#
#    HfirstDownsByRushing  HfirstDownsByPassing  HfirstdownsByPenalty  \
# 0              0.435798              0.271399              0.450704
# 1              0.836576              0.181628              0.408451
# 2              0.762646              0.423800              0.521127
# 3              0.626459              0.150313              0.000000
# 4              0.533074              0.313152              0.690141
#
#    HthirdDownAttempted  ...  VpuntReturnsTouchdowns  VreceivingReceptions  \
# ...

# %%
df_final = pd.merge(df_objects, df_standard, left_index=True, right_index=True)

# %%
df_final
# Out:
#      gameTimeEastern  homeNickname  visitorNickname siteCity  siteState  \
# 0                  4             2               20        6         20
# 1                  2            21               24        5          8
# 2                  2            14               26       30          1
# 3                  2            18                4       11         11
# 4                  2            32               15       24         22
# ..               ...           ...              ...      ...        ...
# 251                2             4               18       29         19
# 252                2            21               27        5          8
# 253               12             5               23        9         21
# 254               12            28                1       35         10
# 255               12            24                8       21         15
#
#      roofType  season  week    siteId  visitorTeamScore  ...  \
# ...

# %%
df_final.to_csv("../data/2019_averages_standized.csv", index=False)
