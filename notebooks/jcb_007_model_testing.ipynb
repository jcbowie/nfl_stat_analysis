# %%
import pandas as pd
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
import pickle

# %%
df = pd.read_csv("../data/processed/final_standardized_data.csv")

# %%
df = df.drop("gameDate", axis=1)

# %%
y_all = df['outcomes']
x_all = df.drop('outcomes', axis=1)

# %%
y_all
# Out:
# 0       H
# 1       H
# 2       V
# 3       H
# 4       H
#        ..
# 2555    H
# 2556    H
# 2557    H
# 2558    H
# 2559    V
# Name: outcomes, Length: 2560, dtype: object

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_all, y_all, test_size=.2, random_state=0)

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train)

print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(x_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.98
# Accuracy of Logistic regression classifier on test set: 0.96
# /Users/caleb/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/caleb/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
df.head()
# Out:
#    gameTimeEastern  homeNickname  visitorNickname  siteCity  siteState  \
# 0                1            29               31        31          1
# 1                2            15               13         2          2
# 2                2             7               12        38          3
# 3                2            27               19        26          4
# 4                2            11               17        16          5
#
#    roofType  season  week    siteId  visitorTeamScore  ...  \
# 0         2     0.0   0.0  0.922054          0.169492  ...
# 1         1     0.0   0.0  0.224070          0.118644  ...
# 2         2     0.0   0.0  0.565787          0.576271  ...
# 3         1     0.0   0.0  0.393889          0.457627  ...
# 4         3     0.0   0.0  0.395552          0.203390  ...
#
#    VreceivingReceptions  VreceivingTouchdowns  VreceivingLong  \
# 0              0.487805              0.142857        0.538462
# ...

# %%
df_no_scores = df.drop(['visitorTeamScore', 'homeTeamScore'], axis=1)

# %%
y_all2 = df['outcomes']
x_all2 = df.drop('outcomes', axis=1)

# %%
x_train2, x_test2, y_train2, y_test2 = model_selection.train_test_split(x_all2, y_all2, test_size=.2, random_state=0)

# %%
logreg2 = LogisticRegression()
logreg2.fit(x_train2, y_train2)

print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(x_train2, y_train2)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(x_test2, y_test2)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.98
# Accuracy of Logistic regression classifier on test set: 0.96
# /Users/caleb/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/caleb/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
df = pd.read_csv("../data/processed/final_standardized_data.csv")
df_2019 = pd.read_csv("../data/2019_averages.csv")

# %%
df.head()
# Out:
#    gameDate  gameTimeEastern  homeNickname  visitorNickname  siteCity  \
# 0         1                1            29               31        31
# 1         2                2            15               13         2
# 2         2                2             7               12        38
# 3         2                2            27               19        26
# 4         2                2            11               17        16
#
#    siteState  roofType  season  week    siteId  ...  VreceivingReceptions  \
# 0          1         2     0.0   0.0  0.922054  ...              0.487805
# 1          2         1     0.0   0.0  0.224070  ...              0.463415
# 2          3         2     0.0   0.0  0.565787  ...              0.341463
# 3          4         1     0.0   0.0  0.393889  ...              0.341463
# 4          5         3     0.0   0.0  0.395552  ...              0.292683
#
#    VreceivingTouchdowns  VreceivingLong  VreceivingYards  VreceivingFumbles  \
# ...

# %%
df_test = pd.read_csv("../data/2019_averages_standized.csv")

# %%
df_test.head()
# Out:
#    gameTimeEastern  homeNickname  visitorNickname siteCity  siteState  \
# 0                4             2               20        6         20
# 1                2            21               24        5          8
# 2                2            14               26       30          1
# 3                2            18                4       11         11
# 4                2            32               15       24         22
#
#    roofType  season  week    siteId  visitorTeamScore  ...  \
# 0         2     0.0   0.0  0.753905               0.0  ...
# 1         2     0.0   0.0  0.152174               0.0  ...
# 2         2     0.0   0.0  0.363233               0.0  ...
# 3         2     0.0   0.0  0.571760               0.0  ...
# 4         1     0.0   0.0  0.127480               0.0  ...
#
#    VpuntReturnsTouchdowns  VreceivingReceptions  VreceivingTouchdowns  \
# 0                0.142857              0.551481              1.000000
# ...

# %%
logreg2.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f4a508987617> in <module>
# ----> 1 logreg2.predict(df_test)
#
# ~/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ~/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     263                                  "yet" % {'name': type(self).__name__})
#     264
# --> 265         X = check_array(X, accept_sparse='csr')
#     266
#     267         n_features = self.coef_.shape[1]
#
# ...

# %%
for col, col_data in df_test.iteritems():
    print(col, ' - ', col_data.unique())
    print()
# Out:
# gameTimeEastern  -  [ 4  2  7 12 13 14 20 19  8 18]
#
# homeNickname  -  [ 2 21 14 18 32 13 17  6 28  9  7 12  8 22 27 23 25 26 31 29  3 19 20 30
#  16 24  5 15  4 10 11  1]
#
# visitorNickname  -  [20 24 26  4 15 25 10 31  3 11  1 16 19 29 30  5  7  8 12 28  9 32 17 22
#  27  2 14  6 18 23 13 21]
#
# siteCity  -  ['6' '5' '30' '11' '24' '23' '17' '8' '35' '4' '38' '1' '13' '12' '26'
#  '27' '3' '19' '25' '31' '7' '10' '14' '15' '21' '9' '2' '29' '18' '16'
#  '34' 'Tottenham' '20' '22']
#
# siteState  -  [20  8  1 11 22  3  9 10 15  6 12 14  4  7 17 16 13 21  2 19 18  5 23]
#
# roofType  -  [2 1 3]
#
# season  -  [0.]
#
# week  -  [0.     0.0625 0.125  0.1875 0.25   0.3125 0.375  0.4375 0.5    0.5625
#  0.625  0.6875 0.75   0.8125 0.875  0.9375 1.    ]
#
# siteId  -  [0.7539046  0.15217391 0.36323343 0.57176024 0.12747995 0.30118193
#  0.21127058 0.         0.90059097 0.85774588 0.55909667 0.82313212
#  0.18130013 0.00358801 0.38455044 0.45947657 0.55867455 0.28303081
# ...

# %%
len(df_test)
# Out:
# 254

# %%
df_test = df_test.loc[df_test['siteCity'] != 'Tottenham']

# %%
logreg2.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f4a508987617> in <module>
# ----> 1 logreg2.predict(df_test)
#
# ~/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# ~/Desktop/Development Practice/Python/nfl/venv/lib/python3.7/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     268         if X.shape[1] != n_features:
#     269             raise ValueError("X has %d features per sample; expecting %d"
# --> 270                              % (X.shape[1], n_features))
#     271
# ...

# %%
counter = 0
for col, col_data in df_test.iteritems():
    print(counter, ' - ', col)
    counter += 1
# Out:
# 0  -  gameTimeEastern
# 1  -  homeNickname
# 2  -  visitorNickname
# 3  -  siteCity
# 4  -  siteState
# 5  -  roofType
# 6  -  season
# 7  -  week
# 8  -  siteId
# 9  -  visitorTeamScore
# 10  -  homeTeamScore
# 11  -  HfirstDownsTotal
# 12  -  HfirstDownsByRushing
# 13  -  HfirstDownsByPassing
# 14  -  HfirstdownsByPenalty
# 15  -  HthirdDownAttempted
# 16  -  HthirdDownMade
# 17  -  HfourthDownAttempted
# 18  -  HfourthDownMade
# 19  -  HoffensiveYardsTotal
# 20  -  HoffensiveAvgYardsPerPlay
# 21  -  HrushingPlays
# 22  -  HrushingYardsTotal
# 23  -  HrushingAvgYardsPerPlay
# 24  -  HrushingLong
# 25  -  HpassingYardsTotal
# 26  -  HpassingNetYards
# 27  -  HpassingAttempts
# 28  -  HpassingCompletions
# 29  -  HpassingInterceptions
# 30  -  HpassingAvgYardsPerPlay
# 31  -  HpassingSacks
# 32  -  HpassingPasserRating
# 33  -  HfieldGoalAttempted
# 34  -  HfieldGoalBlocked
# 35  -  HfieldGoalMade
# 36  -  HextraTwoPointAtt
# 37  -  HextraTwoPointMade
# 38  -  HtotalExtraPointAtt
# ...

# %%
counter = 0
for col, col_data in x_train2.iteritems():
    print(counter, ' - ', col)
    counter += 1
# Out:
# 0  -  gameTimeEastern
# 1  -  homeNickname
# 2  -  visitorNickname
# 3  -  siteCity
# 4  -  siteState
# 5  -  roofType
# 6  -  season
# 7  -  week
# 8  -  siteId
# 9  -  visitorTeamScore
# 10  -  homeTeamScore
# 11  -  HfirstDownsTotal
# 12  -  HfirstDownsByRushing
# 13  -  HfirstDownsByPassing
# 14  -  HfirstdownsByPenalty
# 15  -  HthirdDownAttempted
# 16  -  HthirdDownMade
# 17  -  HfourthDownAttempted
# 18  -  HfourthDownMade
# 19  -  HoffensiveYardsTotal
# 20  -  HoffensiveAvgYardsPerPlay
# 21  -  HrushingPlays
# 22  -  HrushingYardsTotal
# 23  -  HrushingAvgYardsPerPlay
# 24  -  HrushingLong
# 25  -  HpassingYardsTotal
# 26  -  HpassingNetYards
# 27  -  HpassingAttempts
# 28  -  HpassingCompletions
# 29  -  HpassingInterceptions
# 30  -  HpassingAvgYardsPerPlay
# 31  -  HpassingSacks
# 32  -  HpassingPasserRating
# 33  -  HfieldGoalAttempted
# 34  -  HfieldGoalBlocked
# 35  -  HfieldGoalMade
# 36  -  HextraTwoPointAtt
# 37  -  HextraTwoPointMade
# 38  -  HtotalExtraPointAtt
# ...

# %%
def Diff(li1, li2): 
    return (list(set(li1) - set(li2))) 
  
# Driver Code 
li1 = [10, 15, 20, 25, 30, 35, 40] 
li2 = [25, 40, 35] 
print(Diff(df_test.columns, x_train2.columns))
# Out:
# ['VkickingFgAttMade1To19', 'VkickingFgAttMade20To29', 'HkickingFgAttMade1To19', 'HkickingFgAttMade20To29', 'HkickingFgAttMade30To39', 'HkickingFgAttMade40To49', 'HkickingFgAttMade50plus', 'VkickingFgAttMade30To39', 'VkickingFgAttMade40To49', 'VkickingFgAttMade50plus']

# %%
drop = ['VkickingFgAttMade1To19', 'VkickingFgAttMade20To29', 'HkickingFgAttMade1To19', 'HkickingFgAttMade20To29', 'HkickingFgAttMade30To39', 'HkickingFgAttMade40To49', 'HkickingFgAttMade50plus', 'VkickingFgAttMade30To39', 'VkickingFgAttMade40To49', 'VkickingFgAttMade50plus']

# %%
df_test = df_test.drop(drop, axis=1)

# %%
df_results = pd.DataFrame()

# %%
res = logreg2.predict(df_test)

# %%
df_results['outcomes'] = res

# %%
df_results
# Out:
#     outcomes
# 0          V
# 1          H
# 2          H
# 3          H
# 4          V
# ..       ...
# 249        H
# 250        V
# 251        H
# 252        H
# 253        H
#
# [254 rows x 1 columns]

# %%
# df_final = df_test.merge()
merged = pd.merge(df_test, df_results, left_index=True, right_index=True)

# %%
merged.head()
# Out:
#    gameTimeEastern  homeNickname  visitorNickname siteCity  siteState  \
# 0                4             2               20        6         20
# 1                2            21               24        5          8
# 2                2            14               26       30          1
# 3                2            18                4       11         11
# 4                2            32               15       24         22
#
#    roofType  season  week    siteId  visitorTeamScore  ...  \
# 0         2     0.0   0.0  0.753905               0.0  ...
# 1         2     0.0   0.0  0.152174               0.0  ...
# 2         2     0.0   0.0  0.363233               0.0  ...
# 3         2     0.0   0.0  0.571760               0.0  ...
# 4         1     0.0   0.0  0.127480               0.0  ...
#
#    VreceivingReceptions  VreceivingTouchdowns  VreceivingLong  \
# 0              0.551481              1.000000        1.000000
# ...

# %%
merged.to_csv('../data/2019_predictions.csv', index=False)
